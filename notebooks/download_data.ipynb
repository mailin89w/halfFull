# %% [markdown]
# # HalfFull — NHANES Raw Data Download
#
# Downloads all NHANES 2017–March 2020 Pre-Pandemic `.xpt` files needed for the HalfFull project.
#
# **Data source:** [CDC NHANES 2017–2020 Pre-Pandemic](https://wwwn.cdc.gov/nchs/nhanes/continuousnhanes/default.aspx?Cycle=2017-2020)
#
# | Category | Search Page |
# |----------|-------------|
# | Demographics | https://wwwn.cdc.gov/nchs/nhanes/search/datapage.aspx?Component=Demographics&Cycle=2017-2020 |
# | Dietary | https://wwwn.cdc.gov/nchs/nhanes/search/datapage.aspx?Component=Dietary&Cycle=2017-2020 |
# | Examination | https://wwwn.cdc.gov/nchs/nhanes/search/datapage.aspx?Component=Examination&Cycle=2017-2020 |
# | Laboratory | https://wwwn.cdc.gov/nchs/nhanes/search/datapage.aspx?Component=Laboratory&Cycle=2017-2020 |
#
# > Files are saved to `data/raw/nhanes/` (gitignored). Run this notebook once before running any analysis notebooks.

# %%
import urllib.request
from pathlib import Path

REPO_ROOT = Path('..').resolve()
OUT_DIR = REPO_ROOT / 'data' / 'raw' / 'nhanes'
OUT_DIR.mkdir(parents=True, exist_ok=True)

# CDC changed URL structure — new base URL (old: /nchs/nhanes/2017-2020/)
BASE_URL = 'https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2017/DataFiles'

def download_xpt(filename: str, force: bool = False) -> None:
    """Download an NHANES XPT file with validation."""
    dest = OUT_DIR / filename.lower()

    if dest.exists() and not force:
        with open(dest, 'rb') as f:
            header = f.read(20)
        if header.startswith(b'HEADER RECORD'):
            print(f'  SKIP  {filename} (already exists, valid XPT)')
            return
        else:
            print(f'  DEL   {filename} (corrupt, re-downloading)')
            dest.unlink()

    url = f'{BASE_URL}/{filename}'
    print(f'  GET   {filename}')
    req = urllib.request.Request(url, headers={'User-Agent': 'Mozilla/5.0'})
    with urllib.request.urlopen(req) as response:
        data = response.read()

    if not data[:20].startswith(b'HEADER RECORD'):
        raise ValueError(f'Download of {filename} returned unexpected content. URL: {url}')

    dest.write_bytes(data)
    print(f'        saved {len(data)/1_000_000:.1f} MB -> {dest}')

print(f'Saving files to: {OUT_DIR}')
# Out:
# Saving files to: /Users/danielaklein/Arbeit/neuefische/aipm1711/capestone-project/halfFull/data/raw/nhanes

# %% [markdown]
# ---
# ## 1. Demographics

# %%
download_xpt('P_DEMO.XPT')
# Out:
#   GET   P_DEMO.XPT
#         saved 3.6 MB -> /Users/danielaklein/Arbeit/neuefische/aipm1711/capestone-project/halfFull/data/raw/nhanes/p_demo.xpt

# %% [markdown]
# ---
# ## 2. Dietary

# %%
download_xpt('P_DR1TOT.xpt')
# Out:
#   GET   P_DR1TOT.xpt
#         saved 19.2 MB -> /Users/danielaklein/Arbeit/neuefische/aipm1711/capestone-project/halfFull/data/raw/nhanes/p_dr1tot.xpt

# %% [markdown]
# ---
# ## 3. Examination

# %%
download_xpt('P_BMX.xpt')
download_xpt('P_BPXO.xpt')
download_xpt('P_LUX.xpt')
download_xpt('P_OHXREF.xpt')
download_xpt('P_OHXDEN.xpt')
# Out:
#   GET   P_BMX.xpt
#         saved 2.5 MB -> /Users/danielaklein/Arbeit/neuefische/aipm1711/capestone-project/halfFull/data/raw/nhanes/p_bmx.xpt
#   GET   P_BPXO.xpt
#         saved 1.0 MB -> /Users/danielaklein/Arbeit/neuefische/aipm1711/capestone-project/halfFull/data/raw/nhanes/p_bpxo.xpt
#   GET   P_LUX.xpt
#         saved 1.1 MB -> /Users/danielaklein/Arbeit/neuefische/aipm1711/capestone-project/halfFull/data/raw/nhanes/p_lux.xpt
#   GET   P_OHXREF.xpt
#         saved 1.3 MB -> /Users/danielaklein/Arbeit/neuefische/aipm1711/capestone-project/halfFull/data/raw/nhanes/p_ohxref.xpt
#   GET   P_OHXDEN.xpt
#         saved 15.4 MB -> /Users/danielaklein/Arbeit/neuefische/aipm1711/capestone-project/halfFull/data/raw/nhanes/p_ohxden.xpt

# %% [markdown]
# ---
# ## 4. Laboratory

# %%
download_xpt('P_FASTQX.xpt')
download_xpt('P_GLU.xpt')
download_xpt('P_INS.xpt')
download_xpt('P_TCHOL.xpt')
download_xpt('P_HDL.xpt')
download_xpt('P_TRIGLY.xpt')
download_xpt('P_FERTIN.xpt')
download_xpt('P_FETIB.xpt')
download_xpt('P_TFR.xpt')
download_xpt('P_ALB_CR.xpt')
download_xpt('P_BIOPRO.xpt')
download_xpt('P_CBC.xpt')
download_xpt('P_GHB.xpt')
download_xpt('P_HSCRP.xpt')
download_xpt('P_FOLATE.xpt')
download_xpt('P_UCPREG.xpt')
# Out:
#   GET   P_FASTQX.xpt
#         saved 2.1 MB -> /Users/danielaklein/Arbeit/neuefische/aipm1711/capestone-project/halfFull/data/raw/nhanes/p_fastqx.xpt
#   GET   P_GLU.xpt
#         saved 0.2 MB -> /Users/danielaklein/Arbeit/neuefische/aipm1711/capestone-project/halfFull/data/raw/nhanes/p_glu.xpt
#   GET   P_INS.xpt
#         saved 0.2 MB -> /Users/danielaklein/Arbeit/neuefische/aipm1711/capestone-project/halfFull/data/raw/nhanes/p_ins.xpt
#   GET   P_TCHOL.xpt
#         saved 0.3 MB -> /Users/danielaklein/Arbeit/neuefische/aipm1711/capestone-project/halfFull/data/raw/nhanes/p_tchol.xpt
#   GET   P_HDL.xpt
#         saved 0.3 MB -> /Users/danielaklein/Arbeit/neuefische/aipm1711/capestone-project/halfFull/data/raw/nhanes/p_hdl.xpt
#   GET   P_TRIGLY.xpt
#         saved 0.4 MB -> /Users/danielaklein/Arbeit/neuefische/aipm1711/capestone-project/halfFull/data/raw/nhanes/p_trigly.xpt
#   GET   P_FERTIN.xpt
# ...

# %% [markdown]
# ---
# ## 5. Questionnaire
#
# > PHQ-9, Sleep, and Physical Activity are in the Questionnaire component.

# %%
download_xpt('P_ALQ.xpt')
download_xpt('P_BPQ.xpt')
download_xpt('P_CDQ.xpt')
download_xpt('P_DIQ.xpt')
download_xpt('P_DPQ.xpt')
download_xpt('P_HEQ.xpt')
download_xpt('P_HUQ.xpt')
download_xpt('P_KIQ_U.xpt')
download_xpt('P_MCQ.xpt')
download_xpt('P_OCQ.xpt')
download_xpt('P_PAQ.xpt')
download_xpt('P_RHQ.xpt')
download_xpt('P_RXQ_RX.xpt')
download_xpt('P_SLQ.xpt')
download_xpt('P_SMQ.xpt')
download_xpt('P_WHQ.xpt')
# Out:
#   GET   P_ALQ.xpt
#         saved 0.7 MB -> /Users/danielaklein/Arbeit/neuefische/aipm1711/capestone-project/halfFull/data/raw/nhanes/p_alq.xpt
#   GET   P_BPQ.xpt
#         saved 0.9 MB -> /Users/danielaklein/Arbeit/neuefische/aipm1711/capestone-project/halfFull/data/raw/nhanes/p_bpq.xpt
#   GET   P_CDQ.xpt
#         saved 0.9 MB -> /Users/danielaklein/Arbeit/neuefische/aipm1711/capestone-project/halfFull/data/raw/nhanes/p_cdq.xpt
#   GET   P_DIQ.xpt
#         saved 3.4 MB -> /Users/danielaklein/Arbeit/neuefische/aipm1711/capestone-project/halfFull/data/raw/nhanes/p_diq.xpt
#   GET   P_DPQ.xpt
#         saved 0.8 MB -> /Users/danielaklein/Arbeit/neuefische/aipm1711/capestone-project/halfFull/data/raw/nhanes/p_dpq.xpt
#   GET   P_HEQ.xpt
#         saved 0.5 MB -> /Users/danielaklein/Arbeit/neuefische/aipm1711/capestone-project/halfFull/data/raw/nhanes/p_heq.xpt
#   GET   P_HUQ.xpt
# ...

# %% [markdown]
# ---
# ## Summary

# %%
xpt_files = sorted(OUT_DIR.glob('*.xpt'))
print(f'Files in {OUT_DIR}:\n')
for f in xpt_files:
    size_mb = f.stat().st_size / 1_000_000
    print(f'  {f.name:<20}  {size_mb:.1f} MB')
print(f'\nTotal: {len(xpt_files)} files')
# Out:
# Files in /Users/danielaklein/Arbeit/neuefische/aipm1711/capestone-project/halfFull/data/raw/nhanes:
#
#   p_alb_cr.xpt          0.8 MB
#   p_alq.xpt             0.7 MB
#   p_biopro.xpt          3.4 MB
#   p_bmx.xpt             2.5 MB
#   p_bpq.xpt             0.9 MB
#   p_bpxo.xpt            1.0 MB
#   p_cbc.xpt             2.4 MB
#   p_cdq.xpt             0.9 MB
#   p_demo.xpt            3.6 MB
#   p_diq.xpt             3.4 MB
#   p_dpq.xpt             0.8 MB
#   p_dr1tot.xpt          19.2 MB
#   p_fastqx.xpt          2.1 MB
#   p_fertin.xpt          0.3 MB
#   p_fetib.xpt           0.8 MB
#   p_folate.xpt          0.3 MB
#   p_ghb.xpt             0.2 MB
#   p_glu.xpt             0.2 MB
#   p_hdl.xpt             0.3 MB
#   p_heq.xpt             0.5 MB
#   p_hscrp.xpt           0.3 MB
#   p_huq.xpt             0.9 MB
#   p_ins.xpt             0.2 MB
#   p_kiq_u.xpt           1.2 MB
#   p_lux.xpt             1.1 MB
#   p_mcq.xpt             7.6 MB
#   p_ocq.xpt             0.5 MB
# ...
